# %%
import matplotlib.pyplot as plt

# %%
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained("naclbit/trinart_stable_diffusion_v2", revision="diffusers-60k")

image = pipe("A magical dragon flying in front of the Himalaya in manga style").images[0]
# Out:
# Fetching 17 files:   0%|                                                                                                                                                                   | 0/17 [00:00<?, ?it/s]
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1.56k/1.56k [00:00<00:00, 234kB/s]
# ...

# %%
image = pipe("A magical dragon flying in front of the Himalaya in manga style").images[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [14:07<00:00, 16.96s/it]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
image2 = pipe("A magical cloud in the sky with JAIPURIA written on it").images[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [14:50<00:00, 17.81s/it]

# %%
image2
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
